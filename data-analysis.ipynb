# %% [markdown]
# # Introduction
#
# This is an analysis of data from the National Hockey League. This was done for Foundations of Data Science in Fall of 2019. This project was done by Group 5:
# - Andokie Ibeshi
# - Daniel Basilio
# - Prabuddh Dixit
# - Vineeta Kuckreja
#
#
# ## Data Notes
# All of the data in this analysis was fetched from Natural Stat Trick. We used individal player stats for the last five years, regular season data only. Each of the CSVs contains all players who registered any game time throughout that year. We got the data as individual year CSV's for a few reasons:
# - The data was a lot easier to download in chunks
# - The data does not have a year label, so by importing them separately, we can attach year labels from the filenames
#
# ### A note on years
# Hockey seasons span two calendar years because the season starts in October each year, and continues until the playoffs begin, typically in April. There have been events which shift the start/end dates (the World Cup of Hockey in 2016, the Olympics in 2014) but October -> April should apply most years. Each row of data would need to be marked with two years (i.e. 2014-2015) to represent the two calendar years the season was played over. To keep the year data simpler to understand, we will mark all the data as the year that the Stanley Cup was awared. For example, 2014-2015 will be marked as simply 2015, as that seasons Stanley Cup was awarded at the end of the season in 2015.

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
def read_data(filename):
    data = pd.read_csv(
        filename,
        usecols=[
            "Player",
            "GP",
            "Goals",
            "Total Assists",
            "First Assists",
            "Second Assists",
            "Total Points",
            "Shots",
            "SH%",
        ]
    )
    return data

# %%
def clean_data(data, year):
    # Remove all players who failed to register at least 20 games played.
    data = data.drop(data[data["GP"] < 20].index)
    
    # Cast the SH% column to float (it imports as object for some reason)
    data = data.astype({"SH%": "float64"})
    
    # Attach the year as a column
    data["Year"] = year
    
    # Set the index to be a combo of player and year
    data = data.set_index(["Year", "Player"])
    
    return data

# %%
# Read all of our data
fourteen_fifteen = read_data('./yearly-data/14-15.csv')
fifteen_sixteen = read_data('./yearly-data/15-16.csv')
sixteen_seventeen = read_data('./yearly-data/16-17.csv')
seventeen_eighteen = read_data('./yearly-data/17-18.csv')
eighteen_nineteen = read_data('./yearly-data/18-19.csv')

# %%
# Clean all of our data
fourteen_fifteen = clean_data(fourteen_fifteen, "2015")
fifteen_sixteen = clean_data(fifteen_sixteen, "2016")
sixteen_seventeen = clean_data(sixteen_seventeen, "2017")
seventeen_eighteen = clean_data(seventeen_eighteen, "2018")
eighteen_nineteen = clean_data(eighteen_nineteen, "2019")

# %%
# Combine all of Data Frames together
hockey_data = fourteen_fifteen.append([
    fifteen_sixteen,
    sixteen_seventeen,
    seventeen_eighteen,
    eighteen_nineteen,
])

# %%
hockey_data
# Out:
#                          GP  Goals  Total Assists  First Assists  \
# Year Player
# 2015 Jamie Benn          82     35             52             32
#      John Tavares        82     38             48             30
#      Sidney Crosby       77     28             56             31
#      Alex Ovechkin       81     53             28             21
#      Jakub Voracek       82     22             59             31
#      Nicklas Backstrom   82     18             60             31
#      Tyler Seguin        71     37             40             33
#      Daniel Sedin        82     20             56             35
#      Jiri Hudler         78     31             45             29
#      Henrik Sedin        82     18             55             28
#      Nick Foligno        79     31             42             22
#      Claude Giroux       81     25             48             20
#      Vladimir Tarasenko  77     37             36             17
#      Steven Stamkos      82     43             29             22
#      Tyler Johnson       77     29             43             30
#      Ryan Johansen       82     26             45             24
#      Ryan Getzlaf        77     25             45             31
#      Joe Pavelski        82     37             33             22
#      Evgeni Malkin       69     28             42             21
#      Rick Nash           79     42             27             20
#      Logan Couture       82     27             40             23
#      Max Pacioretty      80     37             30             17
#      Henrik Zetterberg   77     17             49             30
#      Jonathan Toews      81     28             38             23
#      Erik Karlsson       82     21             45             25
#      Joe Thornton        78     16             49             28
#      Pavel Datsyuk       63     26             39             24
#      Nikita Kucherov     82     29             36             22
#      Alexander Steen     74     24             40             29
#      Anze Kopitar        79     16             48             30
# ...                      ..    ...            ...            ...
# 2019 Julius Honka        29      0              4              4
#      Sammy Blais         32      2              2              2
#      Jonas Siegenthaler  26      0              4              2
#      Denis Gurianov      21      1              3              1
#      Andreas Martinsen   24      1              3              3
#      Sami Niku           30      1              3              0
#      Oscar Fantenberg    61      2              2              2
#      Ilya Lyubushkin     41      0              4              3
#      Matt Hendricks      26      0              3              3
#      Jori Lehtera        27      1              2              1
#      Zac Rinaldo         23      1              2              2
#      Kevin Gravel        36      0              3              2
#      Anthony Bitetto     36      0              3              1
#      Clark Bishop        20      1              2              2
#      Anders Bjork        20      1              2              1
#      Michael McLeod      21      0              3              1
#      Vinni Lettieri      27      1              2              1
#      Juuso Valimaki      24      1              2              1
#      Tom Pyatt           37      0              2              1
#      Luke Schenn         26      0              2              0
#      Luke Witkowski      34      0              2              2
#      Dalton Prout        20      1              1              1
#      Alex Petrovic       35      0              2              0
#      Jordan Schmaltz     20      0              2              2
#      Josh Brown          37      1              1              0
#      Nick Paul           20      1              1              0
#      Philippe Myers      21      1              1              0
#      Cody McLeod         38      1              0              0
#      Jake Dotchin        20      0              1              1
#      Haydn Fleury        20      0              1              1
#
#                          Second Assists  Total Points  Shots    SH%
# Year Player
# 2015 Jamie Benn                      20            87    253  13.83
#      John Tavares                    18            86    278  13.67
#      Sidney Crosby                   25            84    237  11.81
#      Alex Ovechkin                    7            81    395  13.42
#      Jakub Voracek                   28            81    221   9.95
#      Nicklas Backstrom               29            78    153  11.76
#      Tyler Seguin                     7            77    280  13.21
#      Daniel Sedin                    21            76    226   8.85
#      Jiri Hudler                     16            76    158  19.62
#      Henrik Sedin                    27            73    101  17.82
#      Nick Foligno                    20            73    182  17.03
#      Claude Giroux                   28            73    279   8.96
#      Vladimir Tarasenko              19            73    264  14.02
#      Steven Stamkos                   7            72    268  16.04
#      Tyler Johnson                   13            72    203  14.29
#      Ryan Johansen                   21            71    202  12.87
#      Ryan Getzlaf                    14            70    191  13.09
#      Joe Pavelski                    11            70    261  14.18
#      Evgeni Malkin                   21            70    212  13.21
#      Rick Nash                        7            69    304  13.82
#      Logan Couture                   17            67    264  10.23
#      Max Pacioretty                  13            67    302  12.25
#      Henrik Zetterberg               19            66    227   7.49
#      Jonathan Toews                  15            66    192  14.58
#      Erik Karlsson                   20            66    292   7.19
#      Joe Thornton                    21            65    131  12.21
#      Pavel Datsyuk                   15            65    165  15.76
#      Nikita Kucherov                 14            65    191  15.18
#      Alexander Steen                 11            64    223  10.76
#      Anze Kopitar                    18            64    134  11.94
# ...                                 ...           ...    ...    ...
# 2019 Julius Honka                     0             4     38   0.00
#      Sammy Blais                      0             4     27   7.41
#      Jonas Siegenthaler               2             4     12   0.00
#      Denis Gurianov                   2             4     23   4.35
#      Andreas Martinsen                0             4     21   4.76
#      Sami Niku                        3             4     19   5.26
#      Oscar Fantenberg                 0             4     70   2.86
#      Ilya Lyubushkin                  1             4     27   0.00
#      Matt Hendricks                   0             3     23   0.00
#      Jori Lehtera                     1             3     17   5.88
#      Zac Rinaldo                      0             3     11   9.09
#      Kevin Gravel                     1             3     44   0.00
#      Anthony Bitetto                  2             3     30   0.00
#      Clark Bishop                     0             3     16   6.25
#      Anders Bjork                     1             3     18   5.56
#      Michael McLeod                   2             3     21   0.00
#      Vinni Lettieri                   1             3     40   2.50
#      Juuso Valimaki                   1             3     28   3.57
#      Tom Pyatt                        1             2     29   0.00
#      Luke Schenn                      2             2     30   0.00
#      Luke Witkowski                   0             2     14   0.00
#      Dalton Prout                     0             2     14   7.14
#      Alex Petrovic                    2             2     47   0.00
#      Jordan Schmaltz                  0             2     11   0.00
#      Josh Brown                       1             2     28   3.57
#      Nick Paul                        1             2     30   3.33
#      Philippe Myers                   1             2     25   4.00
#      Cody McLeod                      0             1     22   4.55
#      Jake Dotchin                     0             1      7   0.00
#      Haydn Fleury                     0             1     17   0.00
#
# [3394 rows x 8 columns]
